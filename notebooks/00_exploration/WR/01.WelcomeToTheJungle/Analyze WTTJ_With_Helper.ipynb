# %%
import matplotlib.pyplot as plt
import re
import pandas as pd

# %%
# To have logging in notebook

import logging

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s | %(levelname)s | %(name)s | %(message)s",
    datefmt="%H:%M:%S",
    force=True  # 👈 écrase toute config précédente
)

logger = logging.getLogger(__name__)

# %% [markdown]
# # Accessing Storage Files: Bronze & Silver
# Explore how to access and manipulate job files stored in the bronze and silver layers using `get_storage_from_env()` and the project environment configuration.

# %%
# Map du python path dans le docker
#import sys, os
#sys.path.insert(0, os.path.abspath('../..'))  # remonte à la racine du projet
#from src.config.env import load_project_env

# %% [markdown]
# ## Load Project Environment
# Import and load the project environment configuration to initialize environment variables.

# %%
# Deactivate warning
import warnings
warnings.filterwarnings('ignore')

# Load project environment
from src.config.env import load_project_env
load_project_env()  # Safe to call multiple times (idempotent)
print("✅ Project environment loaded successfully")

from src.config.env import load_project_env
load_project_env()  # safe à rappeler (idempotent)
# Out:
# ✅ Project environment loaded successfully
# PosixPath('/home/jovyan/work/.env')

# %% [markdown]
# ## Storage connections to Bronze / WTTJ

# %%
from src.storage.storage import get_storage_from_env
storage_bronze = get_storage_from_env("bronze", "welcometothejungle")

def get_all_wttj_dt_bronze(storage_bronze):
    prefix=""
    all_dt_bronze = list(storage_bronze.list_prefixes(prefix))
    dates_bronze = [v.replace('dt=', '').replace('/', '') for v in all_dt_bronze if 'dt=' in v]
    sorted_dates_bronze = sorted(dates_bronze)
    return sorted_dates_bronze

def get_all_json_from_dt(storage_bronze, dt_prefix):
    jobs_raw_keys = []
    runid_folders = storage_bronze.list_prefixes(dt_prefix)
    
    for runid_folder in runid_folders:
        if not (runid_folder.startswith("run_id=") or runid_folder.startswith("runid=")):
            continue

        runid_prefix = dt_prefix + runid_folder
        segment_folders = storage_bronze.list_prefixes(runid_prefix)
        for segment_folder in segment_folders:
            if not segment_folder.startswith("segment=jobs_raw"):
                continue
    
            segment_prefix = runid_prefix + segment_folder
            segment_keys = storage_bronze.list_keys(segment_prefix)
            jobs_raw_keys.extend([k for k in segment_keys if k.endswith(".jsonl")])
    return jobs_raw_keys

sorted_dates_bronze = get_all_wttj_dt_bronze(storage_bronze)    
#display(sorted_dates_bronze)

dt_prefix=f'dt={sorted_dates_bronze[0]}/'
#jobs_raw_keys = get_all_json_from_dt(storage_bronze,dt_prefix)

display(jobs_raw_keys)
# Out:
# ['dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000001.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000002.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000003.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000004.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000005.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000006.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000007.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000008.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000009.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000010.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000011.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000012.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000013.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000014.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000015.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000016.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000017.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000018.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000019.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000020.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000021.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000022.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000023.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000024.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000025.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000026.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000027.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000028.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000029.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000030.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000031.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000032.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000033.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000034.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000035.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000036.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000037.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000038.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000039.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000040.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000041.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000042.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000043.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000044.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000045.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000046.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000047.jsonl',
#  'dt=2026-03-04/run_id=20260303T225210Z/segment=jobs_raw/part-000048.jsonl']

# %% [markdown]
# ## Load wttj parquet file with helper

# %%
df = merge_utils.read_wttj_parquet_file_to_df(storage_wttj,"merged_ft_dt=2026-03-07_wttj_dt=2026-03-07.parquet")
# Out:
# 17:13:43 | INFO | src.utils.merge_dataset_utils | 📂 Reading Welcome To The Jungle Silver: merged_ft_dt=2026-03-07_wttj_dt=2026-03-07.parquet
# 17:13:43 | INFO | src.utils.merge_dataset_utils |    Found 1 Parquet files
# 17:13:46 | INFO | src.utils.merge_dataset_utils | ✅ Add merged_ft_dt=2026-03-07_wttj_dt=2026-03-07.parquet in df loaded
# 17:13:46 | INFO | src.utils.merge_dataset_utils | ✅ Welcome To The Jungle: 654,608 offers loaded

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 638047 entries, 0 to 638046
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   id                      638047 non-null  str
#  1   source                  638047 non-null  str
#  2   url                     638047 non-null  str
#  3   title                   638047 non-null  str
#  4   description             638047 non-null  str
#  5   published_at            638047 non-null  datetime64[us]
#  6   updated_at              638017 non-null  datetime64[us]
#  7   unpublished_at          0 non-null       object
#  8   status                  638047 non-null  str
#  9   rome_code               638047 non-null  str
#  10  rome_label              638047 non-null  str
#  11  title_description       638047 non-null  str
#  12  contract_type           638047 non-null  str
#  13  worktime                638047 non-null  str
#  14  experience_level        617994 non-null  str
#  15  experience_description  638031 non-null  str
#  16  naf_code                444540 non-null  str
#  17  job_city                638047 non-null  str
#  18  job_postal_code         638047 non-null  str
#  19  company_name            638047 non-null  str
#  20  company_city            638047 non-null  str
#  21  company_postal_code     638047 non-null  str
#  22  company_url             638047 non-null  str
#  23  salary_min              600735 non-null  float64
#  24  salary_max              600671 non-null  float64
#  25  profile                 638047 non-null  str
#  26  location_department     638047 non-null  str
#  27  skills                  638047 non-null  object
#  28  salary_periodicity      638047 non-null  str
# dtypes: datetime64[us](2), float64(2), object(2), str(23)
# memory usage: 1.3+ GB

# %% [markdown]
# ## Contracts

# %%
# contract_counts = df['contract_type'].value_counts()
contract_counts_by_source = df.groupby('source')['contract_type'].value_counts()

# %% [markdown]
# ### Avant normalisation

# %%
display(df_normalize_contract_counts_by_source.head(30))
#print(f" Libellé unique = {len(df_ft_contract_counts_by_source)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 display(df_normalize_contract_counts_by_source.head(30))
#       2 #print(f" Libellé unique = {len(df_ft_contract_counts_by_source)}")
#
# NameError: name 'df_normalize_contract_counts_by_source' is not defined

# %% [markdown]
# ### Après normalisation

# %%
def normalize_contracts(df, patterns):
    """
    Normalise les types de contrat :
    - Extrait le type principal (CDI, CDD, Intérim, etc.)
    - Extrait le détail (durée, précision)
    - Stocke dans contract_normalized et contract_detail
    """
    def extract_type(value):
        if pd.isna(value):
            return 'Inconnu'
        for pattern, label in patterns:
            if re.search(pattern, str(value)):
                return label
        return str(value)  # garder la valeur originale si pas de match

    def extract_detail(value):
        if pd.isna(value):
            return None
        # Supprimer le pattern trouvé et retourner le reste
        remaining = str(value)
        for pattern, label in patterns:
            remaining = re.sub(pattern, '', remaining).strip()
        # Nettoyer les séparateurs résiduels (-, :, espaces)
        remaining = re.sub(r'^[\s\-:]+|[\s\-:]+$', '', remaining)
        return remaining if remaining else None
    
    df = df.copy()
    df['contract_normalized'] = df['contract_type'].apply(extract_type)
    df['contract_detail']     = df['contract_type'].apply(extract_detail)
    
    return df

# %%
def plot_contract_by_source(df, source, contract_column):
    # Filtrer par source
    df_source = df[df['source'] == source]
    
    # Calcul en pourcentage
    contract_pct = df_source[contract_column].value_counts(normalize=True).mul(100).round(1)
    
    # Graphique
    fig, ax = plt.subplots(figsize=(10, 5))
    contract_pct.plot(kind='bar', ax=ax, color='steelblue', edgecolor='white')
    
    # Afficher les % sur les barres
    for i, v in enumerate(contract_pct):
        ax.text(i, v + 0.5, f'{v}%', ha='center', fontweight='bold')
    
    ax.set_title(f"Répartition des types de contrat — {source}", fontsize=13, fontweight='bold')
    ax.set_xlabel("Type de contrat")
    ax.set_ylabel("Pourcentage (%)")
    ax.set_ylim(0, contract_pct.max() + 10)
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# %%
# Mapping des patterns => type normalisé
patterns = [
    (r'(?i)cdi',                'CDI'),
    (r'(?i)contrat à durée indéterminée',                'CDD'),
    (r'(?i)cdd',                'CDD'),
    (r'(?i)contrat à durée déterminée',                'CDD'),
    (r'(?i)profession\s+lib',   'Profession libérale'),
    (r'(?i)intér?im',           'Intérim'),
    (r'(?i)saisonnier',           'Saisonnier'),
    (r'(?i)profession commerciale',     'Profession commerciale'),
    (r'(?i)franchise',     'Franchise')    
]

# Apply
df_normalize = normalize_contracts(df, patterns)

df_normalize_contract_counts_by_source = df_normalize.groupby('source')['contract_normalized'].value_counts()
print(f"Modalités de contrats FT = {len(df_normalize_contract_counts_by_source.loc['FT'])}")
print(f"Modalités de contrats WTTJ = {len(df_normalize_contract_counts_by_source.loc['WTTJ'])}")

display(df_normalize_contract_counts_by_source.head(30))

plot_contract_by_source(df_normalize, 'FT', 'contract_normalized')
plot_contract_by_source(df_normalize, 'WTTJ', 'contract_normalized')

# %% [markdown]
# ### Expérience

# %%
experience_level_counts_by_source = df.groupby('source')['experience_level'].value_counts()
experience_description_counts_by_source = df.groupby('source')['experience_description'].value_counts()

# %% [markdown]
# ### Avant normalisation

# %% [markdown]
# **FT**
# - experienceExige => D : débutant accepté, E : l’expérience est exigée, S : l’expérience est souhaitée
# - experienceLibelle => Libellé de l’expérience ex : Débutant accepté / 1 ans ...
# - experienceCommentaire => Commentaire sur l’expérience. Ex: Expérience dans la vente souhaitée
#
# On a pas la bonne correspondance de colonne.
# Il faut prendre `experience_level` pour `wttj` et `experience_description` pour FT

# %%
display(experience_level_counts_by_source.head(30))

# %%
display(experience_description_counts_by_source.head(30))

# %%
# Définition des tranches d'expérience avec leurs indices
EXPERIENCE_LEVELS = [
    (0, 'Débutant',    [r'(?i)débutant', r'(?i)0 an', r'(?i)sans expérience']),
    (1, '0-1 an',      [r'(?i)^1 an', r'(?i)^6 mois', r'(?i)^1 mois', r'(?i)^3 mois', r'(?i)less_than_6_months', r'(?i)6_months_to_1_year']),
    (2, '1-2 ans',     [r'(?i)^2 an', r'(?i)1_to_2_years']),
    (3, '2-3 ans',     [r'(?i)^3 an', r'(?i)^24 mois', r'(?i)2_to_3_years' ]),
    (4, '3-5 ans',     [r'(?i)^4 an', r'(?i)^5 an', r'(?i)4_to_5_years', r'(?i)3_to_4_years']),
    (5, '5-10 ans',    [r'(?i)^6 an', r'(?i)^7 an', r'(?i)^8 an', r'(?i)^9 an', r'(?i)^10 an', r'(?i)5_to_7_years', r'(?i)7_to_10_years']),
    (6, '10+ ans',     [r'(?i)^1[1-9] an', r'(?i)^[2-9][0-9] an', r'(?i)10_to_15_years', r'(?i)more_than_15_years']),
    (-1, 'Non précisé', [r'(?i)expérience exigée', r'(?i)expérience souhaitée']),
   
]

def normalize_experience(df, experience_col):
    """
    Normalise les niveaux d'expérience :
    - experience_normalized : label lisible (ex: '0-1 an')
    - experience_index      : indice numérique (ex: 1) pour trier/comparer
    - experience_detail     : valeur originale nettoyée
    """

    def extract_experience(value):
        if pd.isna(value):
            #To DEBUG
            return -1, 'NAN', None
            #return -1, 'Non précisé', None
        
        str_value = str(value).strip()
        
        for index, label, patterns in EXPERIENCE_LEVELS:
            for pattern in patterns:
                if re.search(pattern, str_value):
                    # Détail = valeur originale
                    return index, label, str_value
        
        #return -1, 'Non précisé', str_value
        # To debug
        return -1, value, str_value
    

    results = df[experience_col].apply(extract_experience)
    
    df = df.copy()
    df['experience_index']      = results.apply(lambda x: x[0])
    df['experience_normalized'] = results.apply(lambda x: x[1])
    df['experience_detail']     = results.apply(lambda x: x[2])
    
    return df

# %%
def get_experience_col(row):
    if row['source'] == 'FT':
        return row['experience_description']
    elif row['source'] == 'WTTJ':
        return row['experience_level']
    else:
        return None 

df_normalize['experience_source_composite'] = df.apply(get_experience_col, axis=1)

# Utilisation
df_normalize = normalize_experience(df_normalize,'experience_source_composite')

# Vérification
#df_normalize[['experience_source_composite', 'experience_index', 'experience_normalized', 'experience_detail']].head(20)

display(df_normalize.groupby('source')['experience_normalized'].value_counts())

# %% [markdown]
# ## ROME

# %%
rome_count = df['rome_code'].value_counts()
print(rome_count)
# Out:
# rome_code
# K1304    11963
# J1501    10656
# J1506    10652
# C1504    10488
# M1211     9968
#          ...
# M1845        1
# M1857        1
# M1865        1
# N4130        1
# N4124        1
# Name: count, Length: 1506, dtype: int64

# %% [markdown]
# # Status

# %%
status_counts_by_source = df.groupby('source')['status'].value_counts()

print(status_counts_by_source)
#df.info()
# Out:
# source  status
# FT      published    586768
# WTTJ    published     51279
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

# ─────────────────────────────────────────────
# 1. SUIVI STATUT PAR SOURCE
# ─────────────────────────────────────────────
def statut_par_source(df: pd.DataFrame) -> pd.DataFrame:
    """Tableau croisé : volume par source × statut."""
    return (
        df.groupby(["source", "status"])
        .size()
        .unstack(fill_value=0)
        .assign(TOTAL=lambda x: x.sum(axis=1))
        .sort_values("TOTAL", ascending=False)
    )

def unpublished_par_source(df: pd.DataFrame) -> pd.DataFrame:
    """Volume des offres unpublished par source."""
    return (
        df[df["status"].str.lower() == "unpublished"]
        .groupby("source")
        .size()
        .reset_index(name="nb_unpublished")
        .sort_values("nb_unpublished", ascending=False)
    )


# ─────────────────────────────────────────────
# 2. HISTOGRAMME DURÉE ACTIVE PAR SOURCE
# ─────────────────────────────────────────────

def histogramme_duree_active(
    df: pd.DataFrame,
    source: str,
    date_debut_col: str = "published_at",
    date_fin_col: str = "unpublished_at",
    bins: int = 30,
    max_days: int = 365,
) -> plt.Figure:
    """
    Histogramme de la durée active des annonces pour une source donnée.
    Si date_fin_col est vide, utilise updated_at comme proxy.
    """
    subset = df[df["source"] == source].copy()

    # Choisir la colonne de fin
    if subset[date_fin_col].notna().sum() > 0:
        fin = subset[date_fin_col]
        fin_label = date_fin_col
    else:
        fin = subset["updated_at"]
        fin_label = "updated_at (proxy)"

    subset["duree_jours"] = (fin - subset[date_debut_col]).dt.days
    duree = subset["duree_jours"].dropna()
    duree = duree[(duree >= 0) & (duree <= max_days)]

    if duree.empty:
        print(f"⚠️  Aucune donnée de durée pour : {source}")
        return None

    mediane = duree.median()
    moyenne  = duree.mean()
    n        = len(duree)

    PALETTE = {
        "bar": "#4C72B0", "median": "#DD8452",
        "mean": "#55A868", "bg": "#F8F9FA", "grid": "#E0E0E0",
    }

    fig, ax = plt.subplots(figsize=(10, 5))
    fig.patch.set_facecolor(PALETTE["bg"])
    ax.set_facecolor(PALETTE["bg"])

    ax.hist(duree, bins=bins, color=PALETTE["bar"],
            edgecolor="white", linewidth=0.6, alpha=0.9)

    ax.axvline(mediane, color=PALETTE["median"], linewidth=1.8,
               linestyle="--", label=f"Médiane : {mediane:.0f}j")
    ax.axvline(moyenne, color=PALETTE["mean"], linewidth=1.8,
               linestyle=":",  label=f"Moyenne : {moyenne:.0f}j")

    ax.set_title(
        f"Durée active des annonces — {source}\n"
        f"(n={n:,} | fin = {fin_label})",
        fontsize=13, fontweight="bold", pad=14,
    )
    ax.set_xlabel("Durée active (jours)", fontsize=11)
    ax.set_ylabel("Nombre d'annonces", fontsize=11)
    ax.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f"{int(x):,}"))
    ax.grid(axis="y", color=PALETTE["grid"], linewidth=0.8, zorder=0)
    ax.set_axisbelow(True)
    for spine in ["top", "right"]:
        ax.spines[spine].set_visible(False)

    ax.legend(frameon=False, fontsize=10)
    fig.tight_layout()
    return fig


def histogrammes_toutes_sources(df: pd.DataFrame, sources: list = None, **kwargs):
    """Lance histogramme_duree_active pour chaque source."""
    for src in (sources or df["source"].unique()):
        histogramme_duree_active(df, source=src, **kwargs)
        plt.show()

# %%
# ─────────────────────────────────────────────────────────────────────────────
# Stats
# ─────────────────────────────────────────────────────────────────────────────
#
print(50*"─") 
print(' Statut × source')
print(50*"─") 
print(statut_par_source(df))

print(50*"─") 
print(' Volumes unpublished')
print(50*"─") 
print(unpublished_par_source(df))

# # Histogramme une source
#histogramme_duree_active(df, source="wttj")
#
# # Toutes les sources
#histogrammes_toutes_sources(df, bins=40, max_days=180)
# Out:
# ──────────────────────────────────────────────────
#  Statut × source
# ──────────────────────────────────────────────────
# status  published   TOTAL
# source
# FT         586768  586768
# WTTJ        51279   51279
# ──────────────────────────────────────────────────
#  Volumes unpublished
# ──────────────────────────────────────────────────
# Empty DataFrame
# Columns: [source, nb_unpublished]
# Index: []

# %% [markdown]
# ## Statistics from helper

# %%
if df is not None and not df.empty:
    merge_utils.print_statistics(df)
else    :
    logger.warning("⚠️ Aucune donnée chargée pour les statistiques FT/WTTJ fusionnées")
# Out:
# ================================================================================
# 📊 STATISTICS OF THE MERGED DATASET
# ================================================================================
#
# 📈 GLOBAL STATISTICS
#    Total offers: 654,608
#
# 📦 DISTRIBUTION BY SOURCE
#    FT: 604,613 offers (92.4%)
#    WTTJ: 49,995 offers (7.6%)
#
# 📌 ROME COVERAGE BY SOURCE
#    FT: 604,613/604,613 offers with ROME (100.0%)
#    WTTJ: 49,995/49,995 offers with ROME (100.0%)
#
# 🎯 ROME CODES
#    Offers with ROME: 654,608 (100.0%)
#    Unique ROME codes: 1509
#
# 🏆 TOP 10 ROME CODES
#    K1304: 12,797 (2.0%) - Employé familial / Employée familiale
#    J1501: 11,411 (1.7%) - Aide-soignant / Aide-soignante
#    J1506: 10,730 (1.6%) - Infirmier / Infirmière en soins généraux (IDE)
#    C1504: 10,424 (1.6%) - Conseiller / Conseillère immobilier
#    M1211: 9,966 (1.5%) - Expert-comptable / Experte-comptable
#    M1203: 9,031 (1.4%) - Comptable
#    D1507: 7,899 (1.2%) - Employé / Employée de rayon libre-service
#    K1311: 7,826 (1.2%) - Assistant / Assistante de vie aux familles
#    I1304: 7,607 (1.2%) - Technicien / Technicienne de maintenance industrielle
#    H2903: 6,836 (1.0%) - Tourneur-fraiseur / Tourneuse-fraiseuse
#
# 🧭 ROME CODES BY SOURCE
#
#    Source: FT
#       K1304: 12,761 (2.1%) - Employé familial / Employée familiale
#       J1501: 11,232 (1.9%) - Aide-soignant / Aide-soignante
#       J1506: 10,566 (1.7%) - Infirmier / Infirmière en soins généraux (IDE)
#       M1211: 9,764 (1.6%) - Expert-comptable / Experte-comptable
#       C1504: 9,606 (1.6%) - Conseiller / Conseillère immobilier
#       M1203: 8,604 (1.4%) - Comptable
#       K1311: 7,788 (1.3%) - Assistant / Assistante de vie aux familles
#       I1304: 7,399 (1.2%) - Technicien / Technicienne de maintenance industrielle
#       H2903: 6,793 (1.1%) - Tourneur-fraiseur / Tourneuse-fraiseuse
#       D1507: 6,766 (1.1%) - Employé / Employée de rayon libre-service
#
#    Source: WTTJ
#       K2129: 4,585 (9.2%) - Professeur / Professeure en soutien scolaire
#       K2107: 2,460 (4.9%) - Professeur / Professeure d'éducation physique et sportive (EPS)
#       D1507: 1,133 (2.3%) - Employé / Employée de rayon équipement de la personne
#       M1806: 1,132 (2.3%) - Consultant / Consultante SI Gestion de la Relation Client
#       H1206: 965 (1.9%) - Acousticien / Acousticienne en études, recherche et développement
#       M1811: 944 (1.9%) - Ingénieur / Ingénieure Data Visualisation
#       M1855: 882 (1.8%) - Développeur / Développeuse web mobile
#       D1410: 860 (1.7%) - Représentant commercial / Représentante commerciale
#       C1504: 818 (1.6%) - Agent / Agente de location immobilière
#       C1206: 742 (1.5%) - Gestionnaire de clientèle bancaire
#
# 📊 DISTRIBUTION OF ROME CODES
#    Codes with >1000 offers: 173
#    Codes with 100-1000 offers: 484
#    Codes with 50-100 offers: 200
#    Codes with <50 offers: 652
#
# 📝 CONTRACT TYPES
#    CDI: 317,089 (48.4%)
#    Intérim - 1 Mois: 47,647 (7.3%)
#    full_time: 30,459 (4.7%)
#    Intérim - 6 Mois: 27,256 (4.2%)
#    Intérim - 3 Mois: 20,822 (3.2%)
#
# 📝 CONTRACT TYPES NORMALIZED
#    CDI: 317,830 (48.6%)
#    Intérim: 164,758 (25.2%)
#    CDD: 90,284 (13.8%)
#    full_time: 30,459 (4.7%)
#    Profession libérale: 14,345 (2.2%)
#
# 💼 EXPERIENCE LEVELS
#    E: 305,010 (46.6%)
#    D: 299,597 (45.8%)
#    LESS_THAN_6_MONTHS: 16,636 (2.5%)
#    5_TO_7_YEARS: 3,047 (0.5%)
#    4_TO_5_YEARS: 2,709 (0.4%)
#
# 💼 EXPERIENCE LEVELS NORMALIZED
#    Débutant: 305,854 (46.7%)
#    0-1 an: 129,781 (19.8%)
#    1-2 ans: 73,154 (11.2%)
#    2-3 ans: 49,356 (7.5%)
#    Non précisé: 32,950 (5.0%)
#
# 🎓 SKILLS
#    Offers with skills: 0 (0.0%)
#
# ✅ DATA QUALITY
#    Title provided: 654,608 (100.0%)
#    Description provided: 654,608 (100.0%)
#    URL provided: 654,608 (100.0%)
#    ROME code provided: 654,608 (100.0%)
#
#    📋 FILL RATE FOR ALL FIELDS (sorted by rate)
#       id                            :  654,608/ 654,608 (100.0%)
#       source                        :  654,608/ 654,608 (100.0%)
#       url                           :  654,608/ 654,608 (100.0%)
#       title                         :  654,608/ 654,608 (100.0%)
#       description                   :  654,608/ 654,608 (100.0%)
#       published_at                  :  654,608/ 654,608 (100.0%)
#       status                        :  654,608/ 654,608 (100.0%)
#       rome_code                     :  654,608/ 654,608 (100.0%)
#       rome_label                    :  654,608/ 654,608 (100.0%)
#       title_description             :  654,608/ 654,608 (100.0%)
#       contract_type                 :  654,608/ 654,608 (100.0%)
#       worktime                      :  654,608/ 654,608 (100.0%)
#       job_city                      :  654,608/ 654,608 (100.0%)
#       job_postal_code               :  654,608/ 654,608 (100.0%)
#       company_name                  :  654,608/ 654,608 (100.0%)
#       company_city                  :  654,608/ 654,608 (100.0%)
#       company_postal_code           :  654,608/ 654,608 (100.0%)
#       company_url                   :  654,608/ 654,608 (100.0%)
#       profile                       :  654,608/ 654,608 (100.0%)
#       location_department           :  654,608/ 654,608 (100.0%)
#       skills                        :  654,608/ 654,608 (100.0%)
#       salary_periodicity            :  654,608/ 654,608 (100.0%)
#       contract_normalized           :  654,608/ 654,608 (100.0%)
#       experience_index              :  654,608/ 654,608 (100.0%)
#       experience_normalized         :  654,608/ 654,608 (100.0%)
#       experience_description        :  654,595/ 654,608 (100.0%)
#       updated_at                    :  654,581/ 654,608 (100.0%)
#       experience_level              :  635,469/ 654,608 ( 97.1%)
#       experience_source_composite   :  635,456/ 654,608 ( 97.1%)
#       experience_detail             :  635,456/ 654,608 ( 97.1%)
#       salary_min                    :  618,301/ 654,608 ( 94.5%)
#       salary_max                    :  618,193/ 654,608 ( 94.4%)
#       naf_code                      :  449,926/ 654,608 ( 68.7%)
#       contract_detail               :  328,619/ 654,608 ( 50.2%)
#       unpublished_at                :        0/ 654,608 (  0.0%)
#
#    🔎 DATA QUALITY BY SOURCE
#
#    Source: FT
#       Title provided: 604,613/604,613 (100.0%)
#       Description provided: 604,613/604,613 (100.0%)
#       URL provided: 604,613/604,613 (100.0%)
#       ROME code provided: 604,613/604,613 (100.0%)
#
#    Source: WTTJ
#       Title provided: 49,995/49,995 (100.0%)
#       Description provided: 49,995/49,995 (100.0%)
#       URL provided: 49,995/49,995 (100.0%)
#       ROME code provided: 49,995/49,995 (100.0%)
#
# 🎲 10 RANDOM ENTRIES BY SOURCE
#
#    Source: FT | 10 random entries
#       [01] id=9468884
#            source: FT
#            title: Conducteur d'engins (h/f)
#            rome_code: F1302
#            rome_label: Conducteur / Conductrice d'engins de chantier
#            contract_type: Intérim - 3 Mois
#            url: https://candidat.francetravail.fr/offres/recherche/detail/9468884
#            description: Aprojob, société régionale d'intérim et de recrutements, vous accompagne depuis 2005 au travers d'un cadre de proximité et via des servic...
#            published_at: 2026-02-21 14:44:06
#            updated_at: 2026-02-21 14:44:06
#            unpublished_at: N/A
#            status: published
#            title_description: Conducteur / Conductrice d'engins de chantier
#            worktime: N/A
#            experience_level: E
#            experience_description: 2 An(s)
#            naf_code: 78.20Z
#            job_city: 42 - Roanne
#            job_postal_code: 42300
#            company_name: N/A
#            company_city: 42187
#            company_postal_code: 42300
#            company_url: N/A
#            salary_min: 0.0
#            salary_max: 0.0
#            profile: N/A
#            location_department: 42
#            skills: []
#            salary_periodicity: Horaire de 12.02 Euros à 15.0 Euros
#            contract_normalized: Intérim
#            contract_detail: 3 Mois
#            experience_source_composite: 2 An(s)
#            experience_index: 2
#            experience_normalized: 1-2 ans
#            experience_detail: 2 An(s)
#            ------------------------------------------------------------
#       [02] id=203RKKC
#            source: FT
#            title: Enseignant(e) du second degré voie générale en Technologie (Marciac, Gers)
#            rome_code: K2107
#            rome_label: Professeur / Professeure de collège et de lycée
#            contract_type: CDD - 2 Mois
#            url: https://candidat.francetravail.fr/offres/recherche/detail/203RKKC
#            description: L'académie recrute tout au long de l'année des enseignants contractuels pour assurer des remplacements à temps complet (18 heures) ou inc...
#            published_at: 2026-02-05 16:01:37.777000
#            updated_at: 2026-02-25 21:47:02.755000
#            unpublished_at: N/A
#            status: published
#            title_description: Chargé / Chargée d'enseignement général du second degré
#            worktime: Temps partiel
#            experience_level: D
#            experience_description: Débutant accepté
#            naf_code: 84.12Z
#            job_city: 32 - Gers
#            job_postal_code: N/A
#            company_name: DIRECTION DES SERVICES DEPARTEMENTAUX DE
#            company_city: N/A
#            company_postal_code: N/A
#            company_url: N/A
#            salary_min: 0.0
#            salary_max: 0.0
#            profile: N/A
#            location_department: N/A
#            skills: []
#            salary_periodicity: Mensuel de 2363.0 Euros sur 2.0 mois
#            contract_normalized: CDD
#            contract_detail: 2 Mois
#            experience_source_composite: Débutant accepté
#            experience_index: 0
#            experience_normalized: Débutant
#            experience_detail: Débutant accepté
#            ------------------------------------------------------------
#       [03] id=9800276
#            source: FT
#            title: Agent / Agente immobilier (H/F)
#            rome_code: C1504
#            rome_label: Conseiller / Conseillère immobilier
#            contract_type: Profession libérale
#            url: https://candidat.francetravail.fr/offres/recherche/detail/9800276
#            description: Description du poste REMUNERATION Une rémunération attractive non plafonnée * Touchez jusqu'à 100% des honoraires d'agence de 700 conseil...
#            published_at: 2026-03-03 09:57:36
#            updated_at: 2026-03-03 09:57:36
#            unpublished_at: N/A
#            status: published
#            title_description: Agent / Agente immobilier
#            worktime: N/A
#            experience_level: D
#            experience_description: Débutant accepté
#            naf_code: N/A
#            job_city: 16 - Cognac
#            job_postal_code: 16100
#            company_name: N/A
#            company_city: 16102
#            company_postal_code: 16100
#            company_url: N/A
#            salary_min: 0.0
#            salary_max: 0.0
#            profile: N/A
#            location_department: 16
#            skills: []
#            salary_periodicity: N/A
#            contract_normalized: Profession libérale
#            contract_detail: érale
#            experience_source_composite: Débutant accepté
#            experience_index: 0
#            experience_normalized: Débutant
#            experience_detail: Débutant accepté
#            ------------------------------------------------------------
#       [04] id=6906695
#            source: FT
#            title: INGÉNIEUR.E INFORMATIQUE EN APPUI À LA RECHERCHE (H/F)
#            rome_code: M1801
#            rome_label: Administrateur / Administratrice de systèmes d'information (SI)
#            contract_type: CDD - 36 Mois
#            url: https://candidat.francetravail.fr/offres/recherche/detail/6906695
#            description: Référence CSP: 2025-2142154 Vous serez en charge de son déploiement au sein des laboratoires, de son exploitation, de sa maintenance et d...
#            published_at: 2025-12-21 03:32:30
#            updated_at: 2025-12-21 03:32:30
#            unpublished_at: N/A
#            status: published
#            title_description: Administrateur / Administratrice système informatique
#            worktime: N/A
#            experience_level: E
#            experience_description: 2 An(s)
#            naf_code: N/A
#            job_city: 63 - Puy-de-Dôme
#            job_postal_code: N/A
#            company_name: N/A
#            company_city: N/A
#            company_postal_code: N/A
#            company_url: N/A
#            salary_min: 0.0
#            salary_max: 0.0
#            profile: N/A
#            location_department: N/A
#            skills: []
#            salary_periodicity: N/A
#            contract_normalized: CDD
#            contract_detail: 36 Mois
#            experience_source_composite: 2 An(s)
#            experience_index: 2
#            experience_normalized: 1-2 ans
#            experience_detail: 2 An(s)
#            ------------------------------------------------------------
#       [05] id=9751552
#            source: FT
#            title: Technicien de Maintenance Industrielle (H/F)
#            rome_code: H1404
#            rome_label: Technicien / Technicienne méthodes
#            contract_type: CDI
#            url: https://candidat.francetravail.fr/offres/recherche/detail/9751552
#            description: Nous recherchons un technicien de maintenance industrielle capable de maintenir, réparer et améliorer des systèmes automatisés de product...
#            published_at: 2026-03-02 15:40:02
#            updated_at: 2026-03-02 15:40:02
#            unpublished_at: N/A
#            status: published
#            title_description: Préparateur(trice) méthodes travaux maintenance industrielle
#            worktime: N/A
#            experience_level: E
#            experience_description: 2 An(s)
#            naf_code: 29.32Z
#            job_city: 95 - Survilliers
#            job_postal_code: 95470
#            company_name: N/A
#            company_city: 95604
#            company_postal_code: 95470
#            company_url: N/A
#            salary_min: 0.0
#            salary_max: 0.0
#            profile: N/A
#            location_department: 95
#            skills: []
#            salary_periodicity: Annuel de 20000.0 Euros à 50000.0 Euros
#            contract_normalized: CDI
#            contract_detail: N/A
#            experience_source_composite: 2 An(s)
#            experience_index: 2
#            experience_normalized: 1-2 ans
#            experience_detail: 2 An(s)
#            ------------------------------------------------------------
#       [06] id=9518358
#            source: FT
#            title: OPERATEUR SACHERIE (H/F)
#            rome_code: H3201
#            rome_label: Plasturgiste
#            contract_type: Intérim - 18 Mois
#            url: https://candidat.francetravail.fr/offres/recherche/detail/9518358
#            description: Aprojob, société régionale d'intérim et de recrutements, vous accompagne depuis 2005 au travers d'un cadre de proximité et via des servic...
#            published_at: 2026-02-23 14:45:43
#            updated_at: 2026-02-23 14:45:43
#            unpublished_at: N/A
#            status: published
#            title_description: Opérateur / Opératrice en plasturgie
#            worktime: N/A
#            experience_level: E
#            experience_description: 1 An(s)
#            naf_code: 78.20Z
#            job_city: 43 - Bas-en-Basset
#            job_postal_code: 43210
#            company_name: N/A
#            company_city: 43020
#            company_postal_code: 43210
#            company_url: N/A
#            salary_min: 0.0
#            salary_max: 0.0
#            profile: N/A
#            location_department: 43
#            skills: []
#            salary_periodicity: Horaire de 12.02 Euros à 14.0 Euros
#            contract_normalized: Intérim
#            contract_detail: 18 Mois
#            experience_source_composite: 1 An(s)
#            experience_index: 1
#            experience_normalized: 0-1 an
#            experience_detail: 1 An(s)
#            ------------------------------------------------------------
#       [07] id=9647434
#            source: FT
#            title: CONSEILLER DE VENTE GESTIONNAIRE H/F - VÉGÉTAL
#            rome_code: D1219
#            rome_label: Vendeur / Vendeuse conseil en jardinerie
#            contract_type: CDD - 4 Mois
#            url: https://candidat.francetravail.fr/offres/recherche/detail/9647434
#            description: botanic® est une entreprise familiale qui vit sur des valeurs humaines et des partis pris écologiques. C'est la première entreprise audac...
#            published_at: 2026-02-26 06:52:32
#            updated_at: 2026-02-26 06:52:32
#            unpublished_at: N/A
#            status: published
#            title_description: Vendeur / Vendeuse conseil en jardinerie
#            worktime: Temps plein
#            experience_level: E
#            experience_description: 5 An(s)
#            naf_code: 47.76Z
#            job_city: 56 - Lorient
#            job_postal_code: 56100
#            company_name: Botanic
#            company_city: 56121
#            company_postal_code: 56100
#            company_url: N/A
#            salary_min: 0.0
#            salary_max: 0.0
#            profile: N/A
#            location_department: 56
#            skills: []
#            salary_periodicity: N/A
#            contract_normalized: CDD
#            contract_detail: 4 Mois
#            experience_source_composite: 5 An(s)
#            experience_index: 4
#            experience_normalized: 3-5 ans
#            experience_detail: 5 An(s)
#            ------------------------------------------------------------
#       [08] id=9970129
#            source: FT
#            title: Consultant en outplacement - h/f - Saint-Étienne
#            rome_code: K1801
#            rome_label: Conseiller / Conseillère en insertion professionnelle
#            contract_type: Profession libérale
#            url: https://candidat.francetravail.fr/offres/recherche/detail/9970129
#            description: Et si vous transformiez votre envie de donner du sens à votre carrière en un projet entrepreneurial ambitieux ?Chez Orientaction, leader ...
#            published_at: 2026-03-06 14:39:38
#            updated_at: 2026-03-06 14:39:39
#            unpublished_at: N/A
#            status: published
#            title_description: Conseiller / Conseillère en outplacement
#            worktime: N/A
#            experience_level: D
#            experience_description: Débutant accepté
#            naf_code: N/A
#            job_city: 42 - Saint-Étienne
#            job_postal_code: 42000
#            company_name: N/A
#            company_city: 42218
#            company_postal_code: 42000
#            company_url: N/A
#            salary_min: 0.0
#            salary_max: 0.0
#            profile: N/A
#            location_department: 42
#            skills: []
#            salary_periodicity: N/A
#            contract_normalized: Profession libérale
#            contract_detail: érale
#            experience_source_composite: Débutant accepté
#            experience_index: 0
#            experience_normalized: Débutant
#            experience_detail: Débutant accepté
#            ------------------------------------------------------------
#       [09] id=9785015
#            source: FT
#            title: INFIRMIER VISITE A DOMICILE (H/F)
#            rome_code: J1506
#            rome_label: Infirmier / Infirmière en soins généraux (IDE)
#            contract_type: CDI
#            url: https://candidat.francetravail.fr/offres/recherche/detail/9785015
#            description: Descriptif du poste : Le CH Charles perrens recherche dès que possible un/e IDE pour son unité VAD du pôle Pupea à temps plein Mission gé...
#            published_at: 2026-03-03 07:03:48
#            updated_at: 2026-03-03 07:03:48
#            unpublished_at: N/A
#            status: published
#            title_description: Infirmier / Infirmière de soins généraux
#            worktime: N/A
#            experience_level: D
#            experience_description: Débutant accepté
#            naf_code: N/A
#            job_city: 33 - Bordeaux
#            job_postal_code: 33000
#            company_name: N/A
#            company_city: 33063
#            company_postal_code: 33000
#            company_url: N/A
#            salary_min: 0.0
#            salary_max: 0.0
#            profile: N/A
#            location_department: 33
#            skills: []
#            salary_periodicity: N/A
#            contract_normalized: CDI
#            contract_detail: N/A
#            experience_source_composite: Débutant accepté
#            experience_index: 0
#            experience_normalized: Débutant
#            experience_detail: Débutant accepté
#            ------------------------------------------------------------
#       [10] id=9340356
#            source: FT
#            title: MANAGER D'EQUIPE - BAR-SUR-AUBE H/F
#            rome_code: M1302
#            rome_label: Responsable de Petite ou Moyenne Entreprise -PME-
#            contract_type: CDI
#            url: https://candidat.francetravail.fr/offres/recherche/detail/9340356
#            description: Proches de vous et engagés sur notre territoire CERFRANCE Champagne Nord Est Ile de France, cabinet de conseil et d'expertise comptable, ...
#            published_at: 2026-02-20 06:15:33
#            updated_at: 2026-03-07 06:15:38
#            unpublished_at: N/A
#            status: published
#            title_description: Responsable de centre de profit
#            worktime: N/A
#            experience_level: E
#            experience_description: Expérience exigée
#            naf_code: 69.20Z
#            job_city: 10 - Bar-sur-Aube
#            job_postal_code: 10200
#            company_name: N/A
#            company_city: 10033
#            company_postal_code: 10200
#            company_url: N/A
#            salary_min: 0.0
#            salary_max: 0.0
#            profile: N/A
#            location_department: 10
#            skills: []
#            salary_periodicity: N/A
#            contract_normalized: CDI
#            contract_detail: N/A
#            experience_source_composite: Expérience exigée
#            experience_index: -1
#            experience_normalized: Non précisé
#            experience_detail: Expérience exigée
#            ------------------------------------------------------------
#
#    Source: WTTJ | 10 random entries
#       [01] id=N/A
#            source: WTTJ
#            title: Conseiller de vente Jardin (F/H)
#            rome_code: D1219
#            rome_label: Vendeur / Vendeuse pépiniériste
#            contract_type: temporary
#            url: https://www.welcometothejungle.com/fr/companies/castorama-1/jobs/conseiller-de-vente-jardin-f-h_aix-en-provence_CF_mw5Kkae
#            description: A propos de nousBienvenue sur l’offre de ton futur poste !Chez Castorama, nous avons tous la même ambition : accompagner tous les changem...
#            published_at: 2026-03-03 21:00:17
#            updated_at: 2026-03-03 21:00:25.612271
#            unpublished_at: N/A
#            status: published
#            title_description: N/A
#            worktime: N/A
#            experience_level: N/A
#            experience_description: N/A
#            naf_code: N/A
#            job_city: N/A
#            job_postal_code: N/A
#            company_name: N/A
#            company_city: N/A
#            company_postal_code: N/A
#            company_url: N/A
#            salary_min: N/A
#            salary_max: N/A
#            profile: ProfilTon goøt du commerce et du travail en équipeTon intérêt certain pour les produits de ton secteurTon goøt du challengeTes qualités r...
#            location_department: N/A
#            skills: []
#            salary_periodicity: N/A
#            contract_normalized: temporary
#            contract_detail: temporary
#            experience_source_composite: N/A
#            experience_index: -1
#            experience_normalized: NAN
#            experience_detail: N/A
#            ------------------------------------------------------------
#       [02] id=N/A
#            source: WTTJ
#            title: Sales Executive - THE Challenger F/H
#            rome_code: M1502
#            rome_label: Responsable recrutement
#            contract_type: full_time
#            url: https://www.welcometothejungle.com/fr/companies/eldo/jobs/sales-developer-the-challenger-f-h_toulouse
#            description: 💡Qui sommes-nous ?Eldo, c’est la solution 7-en-1 qui permet aux professionnels et industriels du BTP de se montrer sur le web, convertir ...
#            published_at: 2026-01-11 23:00:18
#            updated_at: 2026-03-03 23:00:23.724618
#            unpublished_at: N/A
#            status: published
#            title_description: N/A
#            worktime: N/A
#            experience_level: N/A
#            experience_description: N/A
#            naf_code: N/A
#            job_city: N/A
#            job_postal_code: N/A
#            company_name: N/A
#            company_city: N/A
#            company_postal_code: N/A
#            company_url: N/A
#            salary_min: 0.0
#            salary_max: N/A
#            profile: N/A
#            location_department: N/A
#            skills: []
#            salary_periodicity: N/A
#            contract_normalized: full_time
#            contract_detail: full_time
#            experience_source_composite: N/A
#            experience_index: -1
#            experience_normalized: NAN
#            experience_detail: N/A
#            ------------------------------------------------------------
#       [03] id=N/A
#            source: WTTJ
#            title: Vendeur F/H - CDI - Temps Plein
#            rome_code: D1507
#            rome_label: Employé / Employée de rayon équipement de la personne
#            contract_type: full_time
#            url: https://www.welcometothejungle.com/fr/companies/ikea-france/jobs/vendeur-f-h-cdi-temps-plein_vitrolles_IF_p2WQzgJ
#            description: Ce que tu feras au quotidienAvec l'appui du Responsable de service Vente, ton rôle est de maximiser les ventes en t'assurant que ta zone ...
#            published_at: 2026-02-10 23:03:01
#            updated_at: 2026-03-03 23:03:26.542334
#            unpublished_at: N/A
#            status: published
#            title_description: N/A
#            worktime: N/A
#            experience_level: N/A
#            experience_description: N/A
#            naf_code: N/A
#            job_city: N/A
#            job_postal_code: N/A
#            company_name: N/A
#            company_city: N/A
#            company_postal_code: N/A
#            company_url: N/A
#            salary_min: N/A
#            salary_max: N/A
#            profile: Qui tu esIKEA, leader international de solutions d’aménagement de la maison, poursuit depuis plus de 40 ans son développement en France a...
#            location_department: N/A
#            skills: []
#            salary_periodicity: N/A
#            contract_normalized: full_time
#            contract_detail: full_time
#            experience_source_composite: N/A
#            experience_index: -1
#            experience_normalized: NAN
#            experience_detail: N/A
#            ------------------------------------------------------------
#       [04] id=N/A
#            source: WTTJ
#            title: Technicien de maintenance lignes aériennes HTB F/H
#            rome_code: I1310
#            rome_label: Micromécanicien / Micromécanicienne de maintenance industrielle
#            contract_type: full_time
#            url: https://www.welcometothejungle.com/fr/companies/rte/jobs/technicien-de-maintenance-lignes-aeriennes-htb-f-h_seyssinet-pariset
#            description: Company DescriptionRTE construit, transforme, exploite et maintient le réseau public de transport d’électricité́ français. Sur le plus gr...
#            published_at: 2026-02-23 17:06:29
#            updated_at: 2026-03-02 23:00:36.513198
#            unpublished_at: N/A
#            status: published
#            title_description: N/A
#            worktime: N/A
#            experience_level: LESS_THAN_6_MONTHS
#            experience_description: N/A
#            naf_code: N/A
#            job_city: N/A
#            job_postal_code: N/A
#            company_name: N/A
#            company_city: N/A
#            company_postal_code: N/A
#            company_url: N/A
#            salary_min: N/A
#            salary_max: N/A
#            profile: Motivé par les challenges du poste et par l'opportunité de travailler au sein d'une entreprise œuvrant en faveur de la transition énergét...
#            location_department: N/A
#            skills: []
#            salary_periodicity: N/A
#            contract_normalized: full_time
#            contract_detail: full_time
#            experience_source_composite: LESS_THAN_6_MONTHS
#            experience_index: 1
#            experience_normalized: 0-1 an
#            experience_detail: LESS_THAN_6_MONTHS
#            ------------------------------------------------------------
#       [05] id=N/A
#            source: WTTJ
#            title: Conseiller·e immobilier transaction
#            rome_code: C1504
#            rome_label: Agent / Agente de location immobilière
#            contract_type: apprenticeship
#            url: https://www.welcometothejungle.com/fr/companies/orpi/jobs/conseiller-e-immobilier-transaction_paris_ORPI_qPNqpNG
#            description: Orpi : qui sommes-nous ?Orpi, coopérative immobilière et leader des réseaux immobiliers en France avec plus de 1 350 agences et 9 000 col...
#            published_at: 2026-01-30 01:01:20
#            updated_at: 2026-03-06 01:01:03.579717
#            unpublished_at: N/A
#            status: published
#            title_description: N/A
#            worktime: N/A
#            experience_level: N/A
#            experience_description: N/A
#            naf_code: N/A
#            job_city: N/A
#            job_postal_code: N/A
#            company_name: N/A
#            company_city: N/A
#            company_postal_code: N/A
#            company_url: N/A
#            salary_min: N/A
#            salary_max: N/A
#            profile: N/A
#            location_department: N/A
#            skills: []
#            salary_periodicity: N/A
#            contract_normalized: apprenticeship
#            contract_detail: apprenticeship
#            experience_source_composite: N/A
#            experience_index: -1
#            experience_normalized: NAN
#            experience_detail: N/A
#            ------------------------------------------------------------
#       [06] id=N/A
#            source: WTTJ
#            title: Chef de projet Sites et Sols Pollués - H/F
#            rome_code: A1313
#            rome_label: Chef / Cheffe de projet études environnementales
#            contract_type: full_time
#            url: https://www.welcometothejungle.com/fr/companies/suez/jobs/ingenieur-de-projet-sites-et-sols-pollues-h-f_metz
#            description: Présent dans 40 pays avec 40 000 collaborateurs, SUEZ apporte des services essentiels pour protéger et améliorer la qualité de vie, face ...
#            published_at: 2026-03-03 11:02:59
#            updated_at: 2026-03-03 11:02:59.322466
#            unpublished_at: N/A
#            status: published
#            title_description: N/A
#            worktime: N/A
#            experience_level: 5_TO_7_YEARS
#            experience_description: N/A
#            naf_code: N/A
#            job_city: N/A
#            job_postal_code: N/A
#            company_name: N/A
#            company_city: N/A
#            company_postal_code: N/A
#            company_url: N/A
#            salary_min: N/A
#            salary_max: N/A
#            profile: Ingénieur avec une expérience de 5 ans minimum d ans le domaine des Site et Sols Pollués, avec la capacité d’assurer la prise en charge d...
#            location_department: N/A
#            skills: []
#            salary_periodicity: N/A
#            contract_normalized: full_time
#            contract_detail: full_time
#            experience_source_composite: 5_TO_7_YEARS
#            experience_index: 5
#            experience_normalized: 5-10 ans
#            experience_detail: 5_TO_7_YEARS
#            ------------------------------------------------------------
#       [07] id=N/A
#            source: WTTJ
#            title: VENDEUR MENUISERIE DECOUPE BOIS (H/F)
#            rome_code: D1212
#            rome_label: Vendeur / Vendeuse en quincaillerie
#            contract_type: full_time
#            url: https://www.welcometothejungle.com/fr/companies/groupement-les-mousquetaires/jobs/vendeur-menuiserie-decoupe-bois-h-f_loches
#            description: Découpe bois et verre, vente menuiserie, quincaillerie
#            published_at: 2026-03-04 23:09:38
#            updated_at: 2026-03-04 23:09:38.105058
#            unpublished_at: N/A
#            status: published
#            title_description: N/A
#            worktime: N/A
#            experience_level: 4_TO_5_YEARS
#            experience_description: N/A
#            naf_code: N/A
#            job_city: N/A
#            job_postal_code: N/A
#            company_name: N/A
#            company_city: N/A
#            company_postal_code: N/A
#            company_url: N/A
#            salary_min: N/A
#            salary_max: N/A
#            profile: Expérience obligatoireInformations supplémentairesCDI 35H00TRAVAILLER LE SAMEDI
#            location_department: N/A
#            skills: []
#            salary_periodicity: N/A
#            contract_normalized: full_time
#            contract_detail: full_time
#            experience_source_composite: 4_TO_5_YEARS
#            experience_index: 4
#            experience_normalized: 3-5 ans
#            experience_detail: 4_TO_5_YEARS
#            ------------------------------------------------------------
#       [08] id=N/A
#            source: WTTJ
#            title: DIPN 21 - Responsable du Bureau des Finances et des Affaires immobilières
#            rome_code: M1204
#            rome_label: Contrôleur / Contrôleuse de gestion sociale
#            contract_type: full_time
#            url: https://www.welcometothejungle.com/fr/companies/ministere-de-l-interieur/jobs/dipn-21-responsable-du-bureau-des-finances-et-des-affaires-...
#            description: Vos missions en quelques mots Groupe RIFSEEP : 1 Vos activités principales : - Gérer une équipe d' 1 agent de catégorie B et de 4 agents ...
#            published_at: 2026-02-11 21:00:31
#            updated_at: 2026-03-04 21:00:35.431791
#            unpublished_at: N/A
#            status: published
#            title_description: N/A
#            worktime: N/A
#            experience_level: N/A
#            experience_description: N/A
#            naf_code: N/A
#            job_city: N/A
#            job_postal_code: N/A
#            company_name: N/A
#            company_city: N/A
#            company_postal_code: N/A
#            company_url: N/A
#            salary_min: N/A
#            salary_max: N/A
#            profile: Profil recherchéDurée attendue sur le poste : 3 ANS MINIMUMVos compétences principales mises en œuvre (listes déroulantes)Avoir des compé...
#            location_department: N/A
#            skills: []
#            salary_periodicity: N/A
#            contract_normalized: full_time
#            contract_detail: full_time
#            experience_source_composite: N/A
#            experience_index: -1
#            experience_normalized: NAN
#            experience_detail: N/A
#            ------------------------------------------------------------
#       [09] id=N/A
#            source: WTTJ
#            title: Alternance - Tests automatisés par l'intégration d'IA F/H
#            rome_code: M1863
#            rome_label: Auditeur informaticien / Auditrice informaticienne
#            contract_type: apprenticeship
#            url: https://www.welcometothejungle.com/fr/companies/schneider-electric/jobs/alternance-tests-automatises-par-l-integration-d-ia-f-h_carros
#            description: Et si votre alternance avait de l’impact ? Classée n°1 des entreprises les plus durables au monde et 2ème au classement HappyTrainees, Sc...
#            published_at: 2026-02-25 23:00:39
#            updated_at: 2026-03-04 23:00:48.047004
#            unpublished_at: N/A
#            status: published
#            title_description: N/A
#            worktime: N/A
#            experience_level: N/A
#            experience_description: N/A
#            naf_code: N/A
#            job_city: N/A
#            job_postal_code: N/A
#            company_name: N/A
#            company_city: N/A
#            company_postal_code: N/A
#            company_url: N/A
#            salary_min: N/A
#            salary_max: N/A
#            profile: N/A
#            location_department: N/A
#            skills: []
#            salary_periodicity: N/A
#            contract_normalized: apprenticeship
#            contract_detail: apprenticeship
#            experience_source_composite: N/A
#            experience_index: -1
#            experience_normalized: NAN
#            experience_detail: N/A
#            ------------------------------------------------------------
#       [10] id=N/A
#            source: WTTJ
#            title: EMPLOYE COMMERCIAL (H/F)
#            rome_code: D1410
#            rome_label: Représentant commercial / Représentante commerciale
#            contract_type: temporary
#            url: https://www.welcometothejungle.com/fr/companies/groupement-les-mousquetaires/jobs/employe-commercial-h-f_paris_GM_bLzwRGm
#            description: Après une période d’intégration et de formation aux méthodes de notre magasin, vous serez chargé de la mise en rayon, du conseil de vos c...
#            published_at: 2026-01-08 23:14:20
#            updated_at: 2026-03-05 23:16:45.366799
#            unpublished_at: N/A
#            status: published
#            title_description: N/A
#            worktime: N/A
#            experience_level: LESS_THAN_6_MONTHS
#            experience_description: N/A
#            naf_code: N/A
#            job_city: N/A
#            job_postal_code: N/A
#            company_name: N/A
#            company_city: N/A
#            company_postal_code: N/A
#            company_url: N/A
#            salary_min: N/A
#            salary_max: N/A
#            profile: Chez Intermarché l’audace et l’envie d’entreprendre sont un véritable état d’esprit. Vous avez envie de vous investir et d’évoluer au sei...
#            location_department: N/A
#            skills: []
#            salary_periodicity: N/A
#            contract_normalized: temporary
#            contract_detail: temporary
#            experience_source_composite: LESS_THAN_6_MONTHS
#            experience_index: 1
#            experience_normalized: 0-1 an
#            experience_detail: LESS_THAN_6_MONTHS
#            ------------------------------------------------------------
#
# ================================================================================
